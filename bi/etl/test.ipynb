# %%
import os
import json
import copy
import pandas as pd
import petl as etl
from pathlib import Path
# from tqdm import tqdm
from tqdm.notebook import tqdm


root_dir = "./dataset/"

# %%
columns_og = ['latitude', 'multilocation', 'longitude', 'remote', 'address_text', 'company_logo_url', 'published_at', 'street', 'company_name', 'skills', 'marker_icon', 'display_offer', 'country_code', 'way_of_apply', 'experience_level', 'id', 'employment_types', 'remote_interview', 'company_url', 'company_size', 'workplace_type', 'open_to_hire_ukrainians', 'title', 'city']

columns_to_check = ('latitude', 'multilocation', 'longitude', 'remote', 'address_text', 'published_at', 'street', 'company_name', 'skills', 'marker_icon', 'display_offer', 'country_code', 'way_of_apply', 'experience_level', 'id', 'remote_interview', 'company_url', 'company_size', 'workplace_type', 'open_to_hire_ukrainians', 'title', 'city')

# %%
def degerate_data(data):
    tmp = []
    # zdegenerowane dane
    # see every offer
    for offer in data:
        offer_cp = copy.copy(offer)
        offer_cp.pop("company_logo_url")
        del offer_cp["employment_types"]
        # cross-check to ensure that all columns all present even with None
        
        cols_to_add = set(columns_to_check) - set(offer_cp.keys())
        
        for col in cols_to_add:
            offer_cp[col] = None
        
        for empl_types in offer["employment_types"]:
            offer_cp["employment_type"] = empl_types["type"]
            offer_cp["salary"] = "Disclosed"
            if empl_types["salary"] is not None:
                offer_cp["from"] = empl_types["salary"]["from"]
                offer_cp["to"] = empl_types["salary"]["to"]
                offer_cp["currency"] = empl_types["salary"]["currency"]
            else:
                offer_cp["from"] = None 
                offer_cp["to"] = None
                offer_cp["currency"] = None
               
                tmp.append(offer_cp)
    return tmp

# %%
from etl_tools import *
FLAG = True

# %%
def przetworz_pliki_w_folderze(folder_path, dim_company, dim_location, workplace_type, employment_type):
    global FLAG
    all_files = []
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'r', encoding='utf-8') as f:
            json_data = json.load(f)
            onefile = degerate_data(json_data)
            all_files.extend(onefile)
    all_files = pd.DataFrame(all_files)
    
    if FLAG:
        dim_company =  create_dim_company(all_files)
        dim_location = create_dim_location(all_files)
        workplace_type = create_workplace_dim(all_files)
        employment_type = create_employmet_dim(all_files)
        FLAG = False
        
        final_fact_table = create_fact_table(all_files, dim_company, dim_location, workplace_type, employment_type)
        
        return final_fact_table, dim_company, dim_location, workplace_type, employment_type
    
    dim_company = pd.concat([dim_company, create_dim_company(all_files)]).drop_duplicates(subset=['company_name', 'company_url', 'company_size'], keep='first').reset_index(drop=True)
    dim_company['company_id'] = dim_company.index + 1
    
    dim_location = pd.concat([dim_location,create_dim_location(all_files)]).drop_duplicates(subset=['street', 'city', 'country_code', 'latitude', 'longitude'], keep='first').reset_index(drop=True)
    dim_location["location_id"] = dim_location.index + 1
    
    workplace_type = pd.concat([workplace_type, create_workplace_dim(all_files)]).drop_duplicates(subset=["workplace_type"], keep='first').reset_index(drop=True)
    workplace_type["workplace_type_id"] = workplace_type.index + 1
    employment_type = pd.concat([employment_type, create_employmet_dim(all_files)]).drop_duplicates(subset=["employment_type"], keep='first').reset_index(drop=True) 
    employment_type["employment_type_id"] = employment_type.index + 1
    
    final_fact_table = create_fact_table(all_files, dim_company, dim_location, workplace_type, employment_type) 
    return final_fact_table, dim_company, dim_location, workplace_type, employment_type

def przetworz_wszystkie_foldery(root_folder):
    final_fact_table = pd.DataFrame()
    dim_company = pd.DataFrame
    dim_location = pd.DataFrame
    workplace_type = pd.DataFrame
    employment_type = pd.DataFrame
    
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        if os.path.isdir(folder_path):            
            ft, dim_company,dim_location, workplace_type, employment_type = przetworz_pliki_w_folderze(folder_path, dim_company, dim_location, workplace_type, employment_type)
            if final_fact_table.empty:
                final_fact_table = ft
            else:
                final_fact_table = pd.concat([final_fact_table, ft], ignore_index=True)
    
    final_fact_table.to_csv("final_fact_table.csv")
    dim_company.to_csv("dim_company.csv")
    dim_location.to_csv("dim_location.csv")
    workplace_type.to_csv("workplace_type.csv")
    employment_type.to_csv("employment_type.csv")

# Ścieżka do głównego katalogu
main_folder = "./dataset/"

# Wywołujemy funkcję przetwarzającą wszystkie foldery
final_fact_table, dim_company, dim_location, workplace_type, employment_type = przetworz_wszystkie_foldery(main_folder)
# Out:
#                                      title                   street      city  \
# 0               Android Developer  (FQWO1)  ul.Marsz.J.Piłsudskiego   Wrocław
# 1  Senior System Integration Test Engineer               Łużycka 8C    Gdynia
# 2                         Programista Java               1 Maja 133  Katowice
# 3                         Programista Java               1 Maja 133  Katowice
# 4                             Scrum Master     al. Jana Pawła II 22  Warszawa
#
#   country_code                      address_text marker_icon workplace_type  \
# 0           PL  ul.Marsz.J.Piłsudskiego, Wrocław        java  partly_remote
# 1           PL                Łużycka 8C, Gdynia     testing         remote
# 2           PL              1 Maja 133, Katowice        java         remote
# 3           PL              1 Maja 133, Katowice        java         remote
# 4           PL    al. Jana Pawła II 22, Warszawa          pm  partly_remote
#
#                          company_name                 company_url  \
# 0                           iRekruter       http://irekruter.com/
# 1  ADVA Optical Networking Sp. z o.o.             http://adva.com
# 2                        KAMSOFT S.A.       http://www.kamsoft.pl
# 3                        KAMSOFT S.A.       http://www.kamsoft.pl
# 4                     Deloitte Polska  http://kariera.deloitte.pl
#
#   company_size  ... display_offer employment_type     salary  from    to  \
# 0         1-20  ...          None             b2b  Disclosed  None  None
# 1         380+  ...          None       permanent  Disclosed  None  None
# 2         700+  ...          None       permanent  Disclosed  None  None
# 3         700+  ...          None       permanent  Disclosed  None  None
# 4        1000+  ...          None       permanent  Disclosed  None  None
#
#   currency company_id  location_id workplace_type_id employment_type_id
# 0     None          1            1                 1                  1
# 1     None          2            2                 2                  2
# 2     None          3            3                 2                  2
# 3     None          3            3                 2                  2
# 4     None          4            4                 1                  2
#
# [5 rows x 31 columns]
#                               title                   street      city  \
# 0         DevOps Engineer: Database  Bogdana Zielińskiego 24    Kraków
# 1  Backend Software Engineer (Java)                Prosta 51  Warszawa
# 2                Senior UX Designer                  Centrum    Kraków
# 3                Senior UX Designer                  Centrum    Kraków
# 4                Senior UX Designer                  Centrum  Warszawa
#
#   country_code                     address_text marker_icon workplace_type  \
# 0         None  Bogdana Zielińskiego 24, Kraków      devops  partly_remote
# 1           PL              Prosta 51, Warszawa        java  partly_remote
# 2           PL                  Centrum, Kraków          ux         remote
# 3           PL                  Centrum, Kraków          ux         remote
# 4           PL                Centrum, Warszawa          ux         remote
#
#          company_name                               company_url company_size  \
# 0         TRANSPOREON           https://www.transporeon.com/pl/          120
# 1  Webfleet Solutions  https://www.webfleet.com/en_gb/webfleet/     501-1000
# 2            CCC S.A.                   https://kariera.ccc.eu/        15000
# 3            CCC S.A.                   https://kariera.ccc.eu/        15000
# 4            CCC S.A.                   https://kariera.ccc.eu/        15000
#
#    ... display_offer employment_type     salary  from    to currency  \
# 0  ...          None       permanent  Disclosed  None  None     None
# 1  ...          None       permanent  Disclosed  None  None     None
# 2  ...          None             b2b  Disclosed  None  None     None
# 3  ...          None             b2b  Disclosed  None  None     None
# 4  ...          None             b2b  Disclosed  None  None     None
#
#   company_id  location_id workplace_type_id employment_type_id
# 0        107          699                 1                  2
# 1        113          163                 1                  2
# 2        134           89                 2                  1
# 3        134           89                 2                  1
# 4        134           66                 2                  1
#
# [5 rows x 31 columns]
#                             title          street          city country_code  \
# 0             Cloud Administrator      Szkolna 54      Bolszewo           PL
# 1  Starszy Specjalista Informatyk      Szkolna 54      Bolszewo           PL
# 2               Android Developer  Sienkiewicza 9  Zielona Góra           PL
# 3               Android Developer  Sienkiewicza 9  Zielona Góra           PL
# 4   Junior MS SQL DevOps Inżynier   Jutrzenki 116      Warszawa           PL
#
#                    address_text marker_icon workplace_type  \
# 0          Szkolna 54, Bolszewo        java  partly_remote
# 1          Szkolna 54, Bolszewo        java  partly_remote
# 2  Sienkiewicza 9, Zielona Góra      mobile         remote
# 3  Sienkiewicza 9, Zielona Góra      mobile         remote
# 4       Jutrzenki 116, Warszawa      devops         office
#
#             company_name                company_url company_size  ...  \
# 0  PORTA KMI Poland S.A.  https://www.porta.com.pl/         1900  ...
# 1  PORTA KMI Poland S.A.  https://www.porta.com.pl/         1900  ...
# 2           Cinkciarz.pl  http://praca.cinkciarz.pl          250  ...
# 3           Cinkciarz.pl  http://praca.cinkciarz.pl          250  ...
# 4              Comp S.A.         http://comp.com.pl          50+  ...
#
#   display_offer employment_type     salary  from    to currency company_id  \
# 0          None       permanent  Disclosed  None  None     None        822
# 1          None       permanent  Disclosed  None  None     None        822
# 2          None       permanent  Disclosed  None  None     None         63
# 3          None       permanent  Disclosed  None  None     None         63
# 4          None             b2b  Disclosed  None  None     None        770
#
#    location_id workplace_type_id employment_type_id
# 0         1070                 1                  2
# 1         1070                 1                  2
# 2          101                 2                  2
# 3          101                 2                  2
# 4          704                 3                  1
#
# [5 rows x 31 columns]
#                                       title             street      city  \
# 0                     Integration Architect          Lubicz 23    Kraków
# 1  Network Engineer – L3 Support Specialist       Szturmowa 2a  Warszawa
# 2                      Salesforce Developer  Łucka 2/4/6 lok.U  Warszawa
# 3                      Salesforce Developer  Łucka 2/4/6 lok.U  Warszawa
# 4                      Solution Architect V   ul. Szturmowa 2a  Warszawa
#
#   country_code                 address_text   marker_icon workplace_type  \
# 0           PL            Lubicz 23, Kraków  architecture  partly_remote
# 1           PL       Szturmowa 2a, Warszawa       support  partly_remote
# 2           PL  Łucka 2/4/6 lok.U, Warszawa         other         remote
# 3           PL  Łucka 2/4/6 lok.U, Warszawa         other         remote
# 4           PL   ul. Szturmowa 2a, Warszawa  architecture  partly_remote
#
#      company_name                   company_url company_size  ...  \
# 0         Allegro         https://allegro.tech/  1001 - 5000  ...
# 1  DXC Technology  https://jobs.dxc.technology/     100 000+  ...
# 2          Booksy         http://www.booksy.com          850  ...
# 3          Booksy         http://www.booksy.com          850  ...
# 4  DXC Technology  https://jobs.dxc.technology/     100 000+  ...
#
#   display_offer employment_type     salary  from    to currency company_id  \
# 0          None       permanent  Disclosed  None  None     None         13
# 1          None       permanent  Disclosed  None  None     None         15
# 2          None             b2b  Disclosed  None  None     None        619
# 3          None             b2b  Disclosed  None  None     None        619
# 4          None       permanent  Disclosed  None  None     None         15
#
#    location_id workplace_type_id employment_type_id
# 0           16                 1                  2
# 1           22                 1                  2
# 2          889                 2                  1
# 3          889                 2                  1
# 4          323                 1                  2
#
# [5 rows x 31 columns]
#                        title                    street       city  \
# 0    Młodszy Programista PHP  Ks. Piotra Wawrzyniaka 2  Komorniki
# 1  Access Management Analyst                   Centrum    Wrocław
# 2         IT Project Manager                   Sucha 3    Wrocław
# 3         IT Project Manager                   Sucha 3    Wrocław
# 4      Junior Linux Operator                Swobodna 1    Wrocław
#
#   country_code                         address_text marker_icon  \
# 0           PL  Ks. Piotra Wawrzyniaka 2, Komorniki         php
# 1           PL                     Centrum, Wrocław   analytics
# 2           PL                     Sucha 3, Wrocław          pm
# 3           PL                     Sucha 3, Wrocław          pm
# 4           PL                  Swobodna 1, Wrocław       admin
#
#   workplace_type                company_name  \
# 0  partly_remote                        Arjo
# 1         remote              Dun&Bradstreet
# 2  partly_remote           PGS Software S.A.
# 3  partly_remote           PGS Software S.A.
# 4         remote  Siemens Digital Logistics
#
#                                          company_url company_size  ...  \
# 0            https://www.arjo.com/int/region-select/        1000+  ...
# 1                               https://www.dnb.com/        5000+  ...
# 2                       https://www.pgs-soft.com/pl/         650+  ...
# 3                       https://www.pgs-soft.com/pl/         650+  ...
# 4  https://www.siemens-digital-logistics.com/home-en         300+  ...
#
#   display_offer employment_type     salary  from    to currency company_id  \
# 0          None       permanent  Disclosed  None  None     None       1166
# 1          None       permanent  Disclosed  None  None     None       1057
# 2          None             b2b  Disclosed  None  None     None        381
# 3          None             b2b  Disclosed  None  None     None        381
# 4          None       permanent  Disclosed  None  None     None        546
#
#    location_id workplace_type_id employment_type_id
# 0         1565                 1                  2
# 1           26                 2                  2
# 2          529                 1                  1
# 3          529                 1                  1
# 4          434                 2                  2
#
# [5 rows x 31 columns]
#                                       title           street      city  \
# 0                        Big Data Developer           Poland    Poland
# 1                             SQL Developer                -   Rzeszów
# 2  Administrator Systemów Bezpieczeństwa IT  ul. Postępu 21C  Warszawa
# 3                    Software Test Engineer       Wołoska 24  Warszawa
# 4                             PHP Developer           remote  Warszawa
#
#   country_code               address_text marker_icon workplace_type  \
# 0           PL             Poland, Poland        data  partly_remote
# 1           PL                 -, Rzeszów        data         remote
# 2           PL  ul. Postępu 21C, Warszawa       admin  partly_remote
# 3           PL       Wołoska 24, Warszawa     testing         remote
# 4           PL           remote, Warszawa         php         remote
#
#                company_name                  company_url company_size  ...  \
# 0   BNP Paribas Bank Polska     http://www.bnpparibas.pl  5001-10 000  ...
# 1                    IT KRD         http://www.it.krd.pl         1000  ...
# 2       LUX MED Sp. z o. o.       https://www.luxmed.pl/        18500  ...
# 3  Inetum Polska Sp. z o.o.        https://inetum.com/pl      200-450  ...
# 4    Simplicity Recruitment  http://www.it-simplicity.pl        10-20  ...
#
#   display_offer employment_type     salary  from    to  currency company_id  \
# 0          None       permanent  Disclosed  None  None      None        156
# 1          None       permanent  Disclosed  None  None      None        424
# 2          None       permanent  Disclosed  None  None      None        987
# 3          None       permanent  Disclosed  None  None      None       1441
# 4          None             b2b  Disclosed  None  None      None        294
#
#   location_id  workplace_type_id employment_type_id
# 0         285                  1                  2
# 1        1289                  2                  2
# 2        1730                  1                  2
# 3        1849                  2                  2
# 4        1913                  2                  1
#
# [5 rows x 31 columns]
#                              title           street       city country_code  \
# 0         C/C++ Embedded Developer          Centrum  Białystok           PL
# 1         C/C++ Embedded Developer          Centrum     Gdańsk           PL
# 2         C/C++ Embedded Developer          Centrum  Bydgoszcz           PL
# 3         C/C++ Embedded Developer          Centrum   Koszalin           PL
# 4  Intern - IT Security Specialist  Wierzbięcice 1B     Poznań           PL
#
#               address_text marker_icon workplace_type company_name  \
# 0       Centrum, Białystok           c         remote        Nokia
# 1          Centrum, Gdańsk           c         remote        Nokia
# 2       Centrum, Bydgoszcz           c         remote        Nokia
# 3        Centrum, Koszalin           c         remote        Nokia
# 4  Wierzbięcice 1B, Poznań    security  partly_remote      Allegro
#
#                   company_url company_size  ... display_offer employment_type  \
# 0  http://nokiawroclaw.pl/en/        3000+  ...          None       permanent
# 1  http://nokiawroclaw.pl/en/        3000+  ...          None       permanent
# 2  http://nokiawroclaw.pl/en/        3000+  ...          None       permanent
# 3  http://nokiawroclaw.pl/en/        3000+  ...          None       permanent
# 4       https://allegro.tech/  1001 - 5000  ...          None       permanent
#
#       salary  from    to  currency company_id location_id  workplace_type_id  \
# 0  Disclosed  None  None      None         30          86                  2
# 1  Disclosed  None  None      None         30        1828                  2
# 2  Disclosed  None  None      None         30        2084                  2
# 3  Disclosed  None  None      None         30        1980                  2
# 4  Disclosed  None  None      None         13        2156                  1
#
#   employment_type_id
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
#
# [5 rows x 31 columns]
#                      title                 street     city country_code  \
# 0          DevOps Engineer    ul. św. Mikołaja 19  Wrocław           PL
# 1  Senior Business Analyst              Sky Tower  Wrocław           PL
# 2  Senior Business Analyst              Sky Tower  Wrocław           PL
# 3   Senior Appian Engineer  Tryton Business House   Gdańsk           PL
# 4   Senior Appian Engineer  Tryton Business House   Gdańsk           PL
#
#                     address_text marker_icon workplace_type  \
# 0   ul. św. Mikołaja 19, Wrocław      devops         remote
# 1             Sky Tower, Wrocław   analytics         remote
# 2             Sky Tower, Wrocław   analytics         remote
# 3  Tryton Business House, Gdańsk          pm         remote
# 4  Tryton Business House, Gdańsk          pm         remote
#
#           company_name                         company_url company_size  ...  \
# 0  S3 Connected Health  https://www.s3connectedhealth.com/          180  ...
# 1              Ciklum             https://jobs.ciklum.com/          220  ...
# 2              Ciklum             https://jobs.ciklum.com/          220  ...
# 3              Ciklum             https://jobs.ciklum.com/          220  ...
# 4              Ciklum             https://jobs.ciklum.com/          220  ...
#
#   way_of_apply employment_type     salary  from    to  currency company_id  \
# 0     redirect       permanent  Disclosed  None  None      None        877
# 1         form             b2b  Disclosed  None  None      None        514
# 2         form             b2b  Disclosed  None  None      None        514
# 3         form             b2b  Disclosed  None  None      None        514
# 4         form             b2b  Disclosed  None  None      None        514
#
#    location_id workplace_type_id  employment_type_id
# 0         1154                 2                   2
# 1          461                 2                   1
# 2          461                 2                   1
# 3         1869                 2                   1
# 4         1869                 2                   1
#
# [5 rows x 31 columns]

# %%
print(final_fact_table.head())
print(dim_company.head())
print(dim_location.head())
print(workplace_type.head())
print(employment_type.head())
